# %% [markdown]
# # Deliverable 1

# %%
# Import dependencies
import random
import numpy as np
import pandas as pd
import requests

from datetime import datetime
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Deliverable 1.3

# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Deliverable 1.4

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Place the lat_lngs into a list
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 747

# %%
# Deliverable 1.5

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_w_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_w_description
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | banda aceh
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | victoria
# Processing Record 4 of Set 1 | nikolskoye
# Processing Record 5 of Set 1 | bayonet point
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 1 | cairns
# Processing Record 10 of Set 1 | kapaa
# Processing Record 11 of Set 1 | jamestown
# Processing Record 12 of Set 1 | penzance
# Processing Record 13 of Set 1 | porangatu
# Processing Record 14 of Set 1 | voyvozh
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | alofi
# Processing Record 17 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 1 | airai
# Processing Record 19 of Set 1 | gigmoto
# Processing Record 20 of Set 1 | sayyan
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | cherskiy
# Processing Record 23 of Set 1 | villamontes
# Processing Record 24 of Set 1 | new norfolk
# Processing Record 25 of Set 1 | zhezkazgan
# Processing Record 26 of Set 1 | san patricio
# Processing Record 27 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 1 | hobart
# Processing Record 29 of Set 1 | leander
# Processing Record 30 of Set 1 | aripuana
# Processing Record 31 of Set 1 | tuktoyaktuk
# Processing Record 32 of Set 1 | lorengau
# Processing Record 33 of Set 1 | qaanaaq
# Processing Record 34 of Set 1 | baykit
# Processing Record 35 of Set 1 | upernavik
# Processing Record 36 of Set 1 | port blair
# Processing Record 37 of Set 1 | fare
# Processing Record 38 of Set 1 | tefe
# Processing Record 39 of Set 1 | port alfred
# Processing Record 40 of Set 1 | atambua
# Processing Record 41 of Set 1 | waterloo
# Processing Record 42 of Set 1 | saint-francois
# Processing Record 43 of Set 1 | busselton
# Processing Record 44 of Set 1 | tselinnoye
# Processing Record 45 of Set 1 | puerto ayora
# Processing Record 46 of Set 1 | albany
# Processing Record 47 of Set 1 | kahului
# Processing Record 48 of Set 1 | rikitea
# Processing Record 49 of Set 1 | faanui
# Processing Record 50 of Set 1 | atuona
# Processing Record 1 of Set 2 | port hardy
# Processing Record 2 of Set 2 | anchorage
# Processing Record 3 of Set 2 | raudeberg
# Processing Record 4 of Set 2 | fortuna
# Processing Record 5 of Set 2 | san jeronimo
# Processing Record 6 of Set 2 | gryazi
# Processing Record 7 of Set 2 | barrow
# Processing Record 8 of Set 2 | saskylakh
# Processing Record 9 of Set 2 | longyearbyen
# Processing Record 10 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 2 | hithadhoo
# Processing Record 12 of Set 2 | atar
# Processing Record 13 of Set 2 | carnarvon
# Processing Record 14 of Set 2 | adrar
# Processing Record 15 of Set 2 | zakamensk
# Processing Record 16 of Set 2 | hamilton
# Processing Record 17 of Set 2 | bolshiye uki
# City not found. Skipping...
# Processing Record 18 of Set 2 | east london
# Processing Record 19 of Set 2 | norman wells
# Processing Record 20 of Set 2 | hasaki
# Processing Record 21 of Set 2 | arraial do cabo
# Processing Record 22 of Set 2 | torbay
# Processing Record 23 of Set 2 | guerrero negro
# Processing Record 24 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 2 | okhotsk
# Processing Record 26 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 2 | severo-kurilsk
# Processing Record 28 of Set 2 | coahuayana
# Processing Record 29 of Set 2 | charters towers
# Processing Record 30 of Set 2 | longlac
# City not found. Skipping...
# Processing Record 31 of Set 2 | khatanga
# Processing Record 32 of Set 2 | cape town
# Processing Record 33 of Set 2 | posse
# Processing Record 34 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 35 of Set 2 | la ronge
# Processing Record 36 of Set 2 | tabuk
# Processing Record 37 of Set 2 | labutta
# City not found. Skipping...
# Processing Record 38 of Set 2 | alta floresta
# Processing Record 39 of Set 2 | hailey
# Processing Record 40 of Set 2 | hovd
# Processing Record 41 of Set 2 | havre-saint-pierre
# Processing Record 42 of Set 2 | pangai
# Processing Record 43 of Set 2 | ippy
# Processing Record 44 of Set 2 | savonlinna
# Processing Record 45 of Set 2 | bengkulu
# Processing Record 46 of Set 2 | saint george
# Processing Record 47 of Set 2 | hofn
# Processing Record 48 of Set 2 | vysha
# Processing Record 49 of Set 2 | sembakung
# Processing Record 50 of Set 2 | marana
# Processing Record 1 of Set 3 | tayu
# Processing Record 2 of Set 3 | butaritari
# Processing Record 3 of Set 3 | kodiak
# Processing Record 4 of Set 3 | sorland
# Processing Record 5 of Set 3 | ribeira grande
# Processing Record 6 of Set 3 | souillac
# Processing Record 7 of Set 3 | mahebourg
# Processing Record 8 of Set 3 | sandwick
# Processing Record 9 of Set 3 | tuatapere
# Processing Record 10 of Set 3 | samur
# Processing Record 11 of Set 3 | hilo
# Processing Record 12 of Set 3 | portland
# Processing Record 13 of Set 3 | bredasdorp
# Processing Record 14 of Set 3 | te anau
# Processing Record 15 of Set 3 | yeppoon
# Processing Record 16 of Set 3 | lebu
# Processing Record 17 of Set 3 | vanimo
# Processing Record 18 of Set 3 | goderich
# Processing Record 19 of Set 3 | mataura
# Processing Record 20 of Set 3 | klaksvik
# Processing Record 21 of Set 3 | imbituba
# Processing Record 22 of Set 3 | thompson
# Processing Record 23 of Set 3 | bonthe
# Processing Record 24 of Set 3 | mar del plata
# Processing Record 25 of Set 3 | moranbah
# Processing Record 26 of Set 3 | aklavik
# Processing Record 27 of Set 3 | manggar
# Processing Record 28 of Set 3 | jiddah
# City not found. Skipping...
# Processing Record 29 of Set 3 | manjacaze
# Processing Record 30 of Set 3 | trincomalee
# Processing Record 31 of Set 3 | clarence town
# Processing Record 32 of Set 3 | bluff
# Processing Record 33 of Set 3 | chokurdakh
# Processing Record 34 of Set 3 | teguise
# Processing Record 35 of Set 3 | inhambane
# Processing Record 36 of Set 3 | ola
# Processing Record 37 of Set 3 | tasiilaq
# Processing Record 38 of Set 3 | nizwa
# Processing Record 39 of Set 3 | gillette
# Processing Record 40 of Set 3 | kaitangata
# Processing Record 41 of Set 3 | honiara
# Processing Record 42 of Set 3 | broken hill
# Processing Record 43 of Set 3 | babanusah
# City not found. Skipping...
# Processing Record 44 of Set 3 | kutum
# Processing Record 45 of Set 3 | tura
# Processing Record 46 of Set 3 | acajutla
# Processing Record 47 of Set 3 | pacific grove
# Processing Record 48 of Set 3 | pevek
# Processing Record 49 of Set 3 | los llanos de aridane
# Processing Record 50 of Set 3 | honningsvag
# Processing Record 1 of Set 4 | husavik
# Processing Record 2 of Set 4 | taitung
# Processing Record 3 of Set 4 | dikson
# Processing Record 4 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 4 | kungurtug
# Processing Record 6 of Set 4 | havoysund
# Processing Record 7 of Set 4 | kumluca
# Processing Record 8 of Set 4 | krasnozerskoye
# Processing Record 9 of Set 4 | talkha
# Processing Record 10 of Set 4 | vaini
# Processing Record 11 of Set 4 | moron
# Processing Record 12 of Set 4 | pijijiapan
# Processing Record 13 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 14 of Set 4 | coquimbo
# Processing Record 15 of Set 4 | namibe
# Processing Record 16 of Set 4 | luba
# Processing Record 17 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 18 of Set 4 | kindersley
# Processing Record 19 of Set 4 | walvis bay
# Processing Record 20 of Set 4 | high prairie
# Processing Record 21 of Set 4 | puro
# Processing Record 22 of Set 4 | rio grande
# Processing Record 23 of Set 4 | chimbote
# Processing Record 24 of Set 4 | mugur-aksy
# Processing Record 25 of Set 4 | richards bay
# Processing Record 26 of Set 4 | brenham
# Processing Record 27 of Set 4 | brae
# Processing Record 28 of Set 4 | hirara
# Processing Record 29 of Set 4 | dromolaxia
# Processing Record 30 of Set 4 | umm lajj
# Processing Record 31 of Set 4 | cranbrook
# Processing Record 32 of Set 4 | agara
# Processing Record 33 of Set 4 | zonalnoye
# City not found. Skipping...
# Processing Record 34 of Set 4 | coetupo
# City not found. Skipping...
# Processing Record 35 of Set 4 | syracuse
# Processing Record 36 of Set 4 | teya
# Processing Record 37 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 4 | gat
# Processing Record 39 of Set 4 | naze
# Processing Record 40 of Set 4 | kifri
# Processing Record 41 of Set 4 | macusani
# Processing Record 42 of Set 4 | cabo san lucas
# Processing Record 43 of Set 4 | galgani
# City not found. Skipping...
# Processing Record 44 of Set 4 | birao
# Processing Record 45 of Set 4 | lagoa
# Processing Record 46 of Set 4 | keetmanshoop
# Processing Record 47 of Set 4 | oranjemund
# Processing Record 48 of Set 4 | cerqueira cesar
# Processing Record 49 of Set 4 | acapulco
# Processing Record 50 of Set 4 | vila velha
# Processing Record 1 of Set 5 | jalu
# Processing Record 2 of Set 5 | vryburg
# Processing Record 3 of Set 5 | amaga
# Processing Record 4 of Set 5 | mayo
# Processing Record 5 of Set 5 | srednekolymsk
# Processing Record 6 of Set 5 | puerto escondido
# Processing Record 7 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 8 of Set 5 | caborca
# Processing Record 9 of Set 5 | vestmannaeyjar
# Processing Record 10 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 5 | vostok
# Processing Record 12 of Set 5 | kochubey
# Processing Record 13 of Set 5 | cayenne
# Processing Record 14 of Set 5 | aksu
# Processing Record 15 of Set 5 | north bend
# Processing Record 16 of Set 5 | pflugerville
# Processing Record 17 of Set 5 | la virtud
# Processing Record 18 of Set 5 | manokwari
# Processing Record 19 of Set 5 | geraldton
# Processing Record 20 of Set 5 | mount gambier
# Processing Record 21 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 5 | bilma
# Processing Record 23 of Set 5 | ilulissat
# Processing Record 24 of Set 5 | narsaq
# Processing Record 25 of Set 5 | merauke
# Processing Record 26 of Set 5 | aykhal
# Processing Record 27 of Set 5 | poopo
# Processing Record 28 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 5 | forrest city
# Processing Record 30 of Set 5 | garmsar
# Processing Record 31 of Set 5 | caucaia
# Processing Record 32 of Set 5 | qasigiannguit
# Processing Record 33 of Set 5 | zaragoza
# Processing Record 34 of Set 5 | leningradskiy
# Processing Record 35 of Set 5 | fasa
# Processing Record 36 of Set 5 | loa janan
# Processing Record 37 of Set 5 | prince rupert
# Processing Record 38 of Set 5 | kavieng
# Processing Record 39 of Set 5 | lethem
# Processing Record 40 of Set 5 | kloulklubed
# Processing Record 41 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 5 | buchanan
# Processing Record 43 of Set 5 | lompoc
# Processing Record 44 of Set 5 | krasnyy chikoy
# Processing Record 45 of Set 5 | yerbogachen
# Processing Record 46 of Set 5 | coihaique
# Processing Record 47 of Set 5 | mengcheng
# Processing Record 48 of Set 5 | chalon-sur-saone
# Processing Record 49 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 50 of Set 5 | monrovia
# Processing Record 1 of Set 6 | malakal
# Processing Record 2 of Set 6 | riyadh
# Processing Record 3 of Set 6 | nanortalik
# Processing Record 4 of Set 6 | shuya
# Processing Record 5 of Set 6 | marfino
# Processing Record 6 of Set 6 | santa barbara
# Processing Record 7 of Set 6 | iracoubo
# Processing Record 8 of Set 6 | bambous virieux
# Processing Record 9 of Set 6 | sao joao da barra
# Processing Record 10 of Set 6 | biak
# Processing Record 11 of Set 6 | turukhansk
# Processing Record 12 of Set 6 | chuy
# Processing Record 13 of Set 6 | sitka
# Processing Record 14 of Set 6 | nara
# Processing Record 15 of Set 6 | saint-philippe
# Processing Record 16 of Set 6 | manacapuru
# Processing Record 17 of Set 6 | eatonton
# Processing Record 18 of Set 6 | yershov
# Processing Record 19 of Set 6 | dalbandin
# Processing Record 20 of Set 6 | mezen
# Processing Record 21 of Set 6 | nalut
# Processing Record 22 of Set 6 | salta
# Processing Record 23 of Set 6 | esperance
# Processing Record 24 of Set 6 | port moresby
# Processing Record 25 of Set 6 | champerico
# Processing Record 26 of Set 6 | ponta delgada
# Processing Record 27 of Set 6 | japura
# Processing Record 28 of Set 6 | quba
# Processing Record 29 of Set 6 | hay river
# Processing Record 30 of Set 6 | pouebo
# Processing Record 31 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 32 of Set 6 | marzuq
# Processing Record 33 of Set 6 | pointe michel
# Processing Record 34 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 35 of Set 6 | ampanihy
# Processing Record 36 of Set 6 | zhangye
# Processing Record 37 of Set 6 | aswan
# Processing Record 38 of Set 6 | avarua
# Processing Record 39 of Set 6 | talnakh
# Processing Record 40 of Set 6 | pisco
# Processing Record 41 of Set 6 | saldanha
# Processing Record 42 of Set 6 | thilogne
# City not found. Skipping...
# Processing Record 43 of Set 6 | berlevag
# Processing Record 44 of Set 6 | tiksi
# Processing Record 45 of Set 6 | ostrovnoy
# Processing Record 46 of Set 6 | urucara
# Processing Record 47 of Set 6 | nchelenge
# Processing Record 48 of Set 6 | axim
# Processing Record 49 of Set 6 | sosnovo-ozerskoye
# Processing Record 50 of Set 6 | meridian
# Processing Record 1 of Set 7 | meulaboh
# Processing Record 2 of Set 7 | rio gallegos
# Processing Record 3 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 4 of Set 7 | matamoros
# Processing Record 5 of Set 7 | mahibadhoo
# Processing Record 6 of Set 7 | ancud
# Processing Record 7 of Set 7 | zyryanka
# Processing Record 8 of Set 7 | bathsheba
# Processing Record 9 of Set 7 | georgetown
# Processing Record 10 of Set 7 | mecca
# Processing Record 11 of Set 7 | ust-maya
# Processing Record 12 of Set 7 | karratha
# Processing Record 13 of Set 7 | sampit
# Processing Record 14 of Set 7 | evensk
# Processing Record 15 of Set 7 | kapasan
# Processing Record 16 of Set 7 | faya
# Processing Record 17 of Set 7 | maridi
# Processing Record 18 of Set 7 | ponta do sol
# Processing Record 19 of Set 7 | kurchum
# Processing Record 20 of Set 7 | poum
# Processing Record 21 of Set 7 | placido de castro
# Processing Record 22 of Set 7 | natal
# Processing Record 23 of Set 7 | cidreira
# Processing Record 24 of Set 7 | horki
# Processing Record 25 of Set 7 | huescar
# Processing Record 26 of Set 7 | san andres
# Processing Record 27 of Set 7 | kyra
# Processing Record 28 of Set 7 | saint-ambroise
# Processing Record 29 of Set 7 | clyde river
# Processing Record 30 of Set 7 | mendi
# Processing Record 31 of Set 7 | pokosnoye
# Processing Record 32 of Set 7 | ukiah
# Processing Record 33 of Set 7 | comodoro rivadavia
# Processing Record 34 of Set 7 | muros
# Processing Record 35 of Set 7 | san gabriel
# Processing Record 36 of Set 7 | krasnoborsk
# Processing Record 37 of Set 7 | melito di porto salvo
# Processing Record 38 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 7 | young
# Processing Record 40 of Set 7 | andros
# Processing Record 41 of Set 7 | iqaluit
# Processing Record 42 of Set 7 | shenjiamen
# Processing Record 43 of Set 7 | vaitape
# Processing Record 44 of Set 7 | iberia
# Processing Record 45 of Set 7 | yabassi
# Processing Record 46 of Set 7 | bolshiye chapurniki
# City not found. Skipping...
# Processing Record 47 of Set 7 | bodden town
# Processing Record 48 of Set 7 | hami
# Processing Record 49 of Set 7 | vardo
# Processing Record 50 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 8 | sabha
# Processing Record 2 of Set 8 | poronaysk
# Processing Record 3 of Set 8 | doha
# Processing Record 4 of Set 8 | gamba
# Processing Record 5 of Set 8 | belmonte
# Processing Record 6 of Set 8 | lata
# Processing Record 7 of Set 8 | ridgecrest
# Processing Record 8 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 9 of Set 8 | conil
# Processing Record 10 of Set 8 | krasnoselkup
# Processing Record 11 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 12 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 13 of Set 8 | vestmanna
# Processing Record 14 of Set 8 | dalvik
# Processing Record 15 of Set 8 | kisesa
# Processing Record 16 of Set 8 | martinez
# Processing Record 17 of Set 8 | kavaratti
# Processing Record 18 of Set 8 | chatham
# Processing Record 19 of Set 8 | necochea
# Processing Record 20 of Set 8 | castro
# Processing Record 21 of Set 8 | luderitz
# Processing Record 22 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 23 of Set 8 | carballo
# Processing Record 24 of Set 8 | eyl
# Processing Record 25 of Set 8 | aberdeen
# Processing Record 26 of Set 8 | raton
# Processing Record 27 of Set 8 | port elizabeth
# Processing Record 28 of Set 8 | pareora
# Processing Record 29 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 8 | taraz
# Processing Record 31 of Set 8 | labuhan
# Processing Record 32 of Set 8 | dawson creek
# Processing Record 33 of Set 8 | klyuchevskiy
# Processing Record 34 of Set 8 | laguna
# Processing Record 35 of Set 8 | khonsa
# Processing Record 36 of Set 8 | bacolod
# Processing Record 37 of Set 8 | vila franca do campo
# Processing Record 38 of Set 8 | hobyo
# Processing Record 39 of Set 8 | raymondville
# Processing Record 40 of Set 8 | kruisfontein
# Processing Record 41 of Set 8 | lagoa santa
# Processing Record 42 of Set 8 | amurrio
# Processing Record 43 of Set 8 | kieta
# Processing Record 44 of Set 8 | tarumovka
# Processing Record 45 of Set 8 | rawson
# Processing Record 46 of Set 8 | tevriz
# Processing Record 47 of Set 8 | bhimunipatnam
# Processing Record 48 of Set 8 | mirabad
# Processing Record 49 of Set 8 | chibuto
# Processing Record 50 of Set 8 | sakakah
# Processing Record 1 of Set 9 | zyryanovsk
# Processing Record 2 of Set 9 | mapiripan
# Processing Record 3 of Set 9 | koratla
# Processing Record 4 of Set 9 | port hawkesbury
# Processing Record 5 of Set 9 | pitkyaranta
# Processing Record 6 of Set 9 | znamenskoye
# Processing Record 7 of Set 9 | puerto leguizamo
# Processing Record 8 of Set 9 | constitucion
# Processing Record 9 of Set 9 | mangrol
# Processing Record 10 of Set 9 | bethel
# Processing Record 11 of Set 9 | tazovskiy
# Processing Record 12 of Set 9 | pimenta bueno
# Processing Record 13 of Set 9 | namatanai
# Processing Record 14 of Set 9 | codrington
# Processing Record 15 of Set 9 | kati
# Processing Record 16 of Set 9 | heihe
# Processing Record 17 of Set 9 | warmbad
# Processing Record 18 of Set 9 | xining
# Processing Record 19 of Set 9 | buqayq
# City not found. Skipping...
# Processing Record 20 of Set 9 | avera
# Processing Record 21 of Set 9 | shizunai
# Processing Record 22 of Set 9 | yar-sale
# Processing Record 23 of Set 9 | ibra
# Processing Record 24 of Set 9 | daru
# Processing Record 25 of Set 9 | elmina
# Processing Record 26 of Set 9 | atbasar
# Processing Record 27 of Set 9 | ocos
# Processing Record 28 of Set 9 | kargil
# Processing Record 29 of Set 9 | pasighat
# Processing Record 30 of Set 9 | makakilo city
# Processing Record 31 of Set 9 | elat
# Processing Record 32 of Set 9 | santa rosa
# Processing Record 33 of Set 9 | tadine
# Processing Record 34 of Set 9 | sola
# Processing Record 35 of Set 9 | beisfjord
# Processing Record 36 of Set 9 | ozernovskiy
# Processing Record 37 of Set 9 | jurado
# Processing Record 38 of Set 9 | camana
# Processing Record 39 of Set 9 | ploemeur
# Processing Record 40 of Set 9 | yilan
# Processing Record 41 of Set 9 | khovu-aksy
# Processing Record 42 of Set 9 | onega
# Processing Record 43 of Set 9 | sistranda
# Processing Record 44 of Set 9 | general roca
# Processing Record 45 of Set 9 | ishinomaki
# Processing Record 46 of Set 9 | lahat
# Processing Record 47 of Set 9 | balabac
# Processing Record 48 of Set 9 | falmouth
# Processing Record 49 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 50 of Set 9 | marv dasht
# City not found. Skipping...
# Processing Record 1 of Set 10 | kouroussa
# Processing Record 2 of Set 10 | carolina
# Processing Record 3 of Set 10 | orgtrud
# Processing Record 4 of Set 10 | sarangani
# Processing Record 5 of Set 10 | saint-georges
# Processing Record 6 of Set 10 | marsh harbour
# Processing Record 7 of Set 10 | aviles
# Processing Record 8 of Set 10 | kamensk-shakhtinskiy
# Processing Record 9 of Set 10 | enshi
# Processing Record 10 of Set 10 | tunduru
# City not found. Skipping...
# Processing Record 11 of Set 10 | sur
# Processing Record 12 of Set 10 | sibolga
# Processing Record 13 of Set 10 | manono
# Processing Record 14 of Set 10 | lazaro cardenas
# Processing Record 15 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 16 of Set 10 | susanville
# Processing Record 17 of Set 10 | fort saint john
# City not found. Skipping...
# Processing Record 18 of Set 10 | lakes entrance
# Processing Record 19 of Set 10 | abu samrah
# Processing Record 20 of Set 10 | vanavara
# Processing Record 21 of Set 10 | amot
# Processing Record 22 of Set 10 | russell
# Processing Record 23 of Set 10 | yeletskiy
# City not found. Skipping...
# Processing Record 24 of Set 10 | mayya
# Processing Record 25 of Set 10 | burgos
# Processing Record 26 of Set 10 | kidal
# Processing Record 27 of Set 10 | naples
# Processing Record 28 of Set 10 | inirida
# Processing Record 29 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 10 | viedma
# Processing Record 31 of Set 10 | sao filipe
# Processing Record 32 of Set 10 | port macquarie
# Processing Record 33 of Set 10 | nakamura
# Processing Record 34 of Set 10 | okha
# Processing Record 35 of Set 10 | thaton
# Processing Record 36 of Set 10 | encheng
# Processing Record 37 of Set 10 | toora-khem
# Processing Record 38 of Set 10 | provideniya
# Processing Record 39 of Set 10 | cabra
# Processing Record 40 of Set 10 | sinnamary
# Processing Record 41 of Set 10 | cambridge
# Processing Record 42 of Set 10 | sipoo
# Processing Record 43 of Set 10 | powell river
# Processing Record 44 of Set 10 | dwarka
# Processing Record 45 of Set 10 | west wendover
# Processing Record 46 of Set 10 | iralaya
# Processing Record 47 of Set 10 | kuhestan
# City not found. Skipping...
# Processing Record 48 of Set 10 | kumba
# Processing Record 49 of Set 10 | bursol
# City not found. Skipping...
# Processing Record 50 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 1 of Set 11 | yarmouth
# Processing Record 2 of Set 11 | yoichi
# Processing Record 3 of Set 11 | ajdabiya
# Processing Record 4 of Set 11 | komsomolskiy
# Processing Record 5 of Set 11 | kandrian
# Processing Record 6 of Set 11 | kalmunai
# Processing Record 7 of Set 11 | hualmay
# Processing Record 8 of Set 11 | bonfim
# Processing Record 9 of Set 11 | mareeba
# Processing Record 10 of Set 11 | praya
# Processing Record 11 of Set 11 | sal rei
# Processing Record 12 of Set 11 | huarmey
# Processing Record 13 of Set 11 | obluche
# City not found. Skipping...
# Processing Record 14 of Set 11 | siparia
# Processing Record 15 of Set 11 | san fernando
# Processing Record 16 of Set 11 | divnomorskoye
# Processing Record 17 of Set 11 | puerto carreno
# Processing Record 18 of Set 11 | nouadhibou
# Processing Record 19 of Set 11 | kiunga
# Processing Record 20 of Set 11 | amahai
# Processing Record 21 of Set 11 | lavumisa
# Processing Record 22 of Set 11 | broome
# Processing Record 23 of Set 11 | sterling
# Processing Record 24 of Set 11 | pandan
# Processing Record 25 of Set 11 | victor harbor
# Processing Record 26 of Set 11 | xai-xai
# Processing Record 27 of Set 11 | chernyanka
# Processing Record 28 of Set 11 | zhigansk
# Processing Record 29 of Set 11 | paka
# Processing Record 30 of Set 11 | lasa
# Processing Record 31 of Set 11 | puerto madryn
# Processing Record 32 of Set 11 | aguada de pasajeros
# Processing Record 33 of Set 11 | mopti
# Processing Record 34 of Set 11 | gobabis
# Processing Record 35 of Set 11 | hambantota
# Processing Record 36 of Set 11 | saint anthony
# Processing Record 37 of Set 11 | mogadishu
# Processing Record 38 of Set 11 | pedernales
# Processing Record 39 of Set 11 | miles city
# Processing Record 40 of Set 11 | atotonilco el alto
# Processing Record 41 of Set 11 | korla
# Processing Record 42 of Set 11 | birin
# Processing Record 43 of Set 11 | tygda
# Processing Record 44 of Set 11 | fereydun kenar
# Processing Record 45 of Set 11 | bandarbeyla
# Processing Record 46 of Set 11 | kang
# Processing Record 47 of Set 11 | leh
# Processing Record 48 of Set 11 | pontes e lacerda
# Processing Record 49 of Set 11 | marawi
# Processing Record 50 of Set 11 | andreapol
# Processing Record 1 of Set 12 | changqing
# Processing Record 2 of Set 12 | conde
# Processing Record 3 of Set 12 | kupang
# Processing Record 4 of Set 12 | mastic beach
# Processing Record 5 of Set 12 | sulphur
# Processing Record 6 of Set 12 | port lincoln
# Processing Record 7 of Set 12 | edson
# Processing Record 8 of Set 12 | biryusinsk
# Processing Record 9 of Set 12 | noumea
# Processing Record 10 of Set 12 | lake cowichan
# Processing Record 11 of Set 12 | nkoteng
# Processing Record 12 of Set 12 | puerto narino
# Processing Record 13 of Set 12 | ahipara
# Processing Record 14 of Set 12 | lyuban
# Processing Record 15 of Set 12 | muroto
# Processing Record 16 of Set 12 | dukat
# Processing Record 17 of Set 12 | conakry
# Processing Record 18 of Set 12 | tezu
# Processing Record 19 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 20 of Set 12 | semey
# Processing Record 21 of Set 12 | kimbe
# Processing Record 22 of Set 12 | timbio
# City not found. Skipping...
# Processing Record 23 of Set 12 | olafsvik
# Processing Record 24 of Set 12 | mandalgovi
# Processing Record 25 of Set 12 | barentu
# Processing Record 26 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 27 of Set 12 | mandla
# Processing Record 28 of Set 12 | kenai
# Processing Record 29 of Set 12 | kamenka
# Processing Record 30 of Set 12 | rudbar
# Processing Record 31 of Set 12 | rio bananal
# Processing Record 32 of Set 12 | bowen
# Processing Record 33 of Set 12 | exeter
# Processing Record 34 of Set 12 | mazagao
# Processing Record 35 of Set 12 | turka
# Processing Record 36 of Set 12 | whitefish
# Processing Record 37 of Set 12 | pasni
# Processing Record 38 of Set 12 | lavrentiya
# Processing Record 39 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 40 of Set 12 | carira
# Processing Record 41 of Set 12 | mehamn
# Processing Record 42 of Set 12 | vao
# Processing Record 43 of Set 12 | leduc
# Processing Record 44 of Set 12 | naifaru
# Processing Record 45 of Set 12 | cedar city
# Processing Record 46 of Set 12 | san juan
# Processing Record 47 of Set 12 | moindou
# Processing Record 48 of Set 12 | upata
# Processing Record 49 of Set 12 | chegutu
# Processing Record 50 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 13 | thessalon
# Processing Record 2 of Set 13 | bogorodskoye
# Processing Record 3 of Set 13 | karla
# Processing Record 4 of Set 13 | makamba
# Processing Record 5 of Set 13 | san cristobal
# Processing Record 6 of Set 13 | timbiras
# Processing Record 7 of Set 13 | pinsk
# Processing Record 8 of Set 13 | bend
# Processing Record 9 of Set 13 | nizhniy tsasuchey
# Processing Record 10 of Set 13 | lae
# Processing Record 11 of Set 13 | tongren
# Processing Record 12 of Set 13 | oussouye
# Processing Record 13 of Set 13 | galesong
# Processing Record 14 of Set 13 | xam nua
# Processing Record 15 of Set 13 | simplicio mendes
# Processing Record 16 of Set 13 | anloga
# Processing Record 17 of Set 13 | katsuura
# Processing Record 18 of Set 13 | nishihara
# Processing Record 19 of Set 13 | taoudenni
# Processing Record 20 of Set 13 | college
# Processing Record 21 of Set 13 | miyako
# Processing Record 22 of Set 13 | kouango
# Processing Record 23 of Set 13 | chara
# Processing Record 24 of Set 13 | quatre cocos
# Processing Record 25 of Set 13 | porto novo
# Processing Record 26 of Set 13 | eruwa
# Processing Record 27 of Set 13 | trinidad
# Processing Record 28 of Set 13 | tessalit
# Processing Record 29 of Set 13 | kayerkan
# Processing Record 30 of Set 13 | ostersund
# Processing Record 31 of Set 13 | udachnyy
# Processing Record 32 of Set 13 | saint-joseph
# Processing Record 33 of Set 13 | nang rong
# Processing Record 34 of Set 13 | fonte boa
# Processing Record 35 of Set 13 | albury
# Processing Record 36 of Set 13 | saint-augustin
# Processing Record 37 of Set 13 | waitati
# Processing Record 38 of Set 13 | samarai
# Processing Record 39 of Set 13 | santa cruz del sur
# Processing Record 40 of Set 13 | zaysan
# Processing Record 41 of Set 13 | blagoyevo
# Processing Record 42 of Set 13 | ulaangom
# Processing Record 43 of Set 13 | guayaramerin
# Processing Record 44 of Set 13 | deputatskiy
# Processing Record 45 of Set 13 | hervey bay
# Processing Record 46 of Set 13 | zolotinka
# City not found. Skipping...
# Processing Record 47 of Set 13 | dunedin
# Processing Record 48 of Set 13 | chumikan
# Processing Record 49 of Set 13 | bogovarovo
# Processing Record 50 of Set 13 | orumiyeh
# Processing Record 1 of Set 14 | sahibganj
# Processing Record 2 of Set 14 | grajau
# Processing Record 3 of Set 14 | dingle
# Processing Record 4 of Set 14 | wuwei
# Processing Record 5 of Set 14 | mao
# Processing Record 6 of Set 14 | graaff-reinet
# Processing Record 7 of Set 14 | isangel
# Processing Record 8 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 9 of Set 14 | qeshm
# Processing Record 10 of Set 14 | chiredzi
# Processing Record 11 of Set 14 | umea
# Processing Record 12 of Set 14 | sorong
# Processing Record 13 of Set 14 | amalapuram
# Processing Record 14 of Set 14 | wajir
# Processing Record 15 of Set 14 | caravelas
# Processing Record 16 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 17 of Set 14 | cuiluan
# Processing Record 18 of Set 14 | grindavik
# Processing Record 19 of Set 14 | yulara
# Processing Record 20 of Set 14 | pangnirtung
# Processing Record 21 of Set 14 | dauphin
# Processing Record 22 of Set 14 | moyale
# Processing Record 23 of Set 14 | yumen
# Processing Record 24 of Set 14 | mbini
# Processing Record 25 of Set 14 | nhulunbuy
# Processing Record 26 of Set 14 | davila
# Processing Record 27 of Set 14 | ust-kuyga
# Processing Record 28 of Set 14 | eenhana
# Processing Record 29 of Set 14 | ambon
# Processing Record 30 of Set 14 | moerai
# Processing Record 31 of Set 14 | nome
# Processing Record 32 of Set 14 | touros
# Processing Record 33 of Set 14 | galiwinku
# City not found. Skipping...
# Processing Record 34 of Set 14 | zonguldak
# Processing Record 35 of Set 14 | labuan
# Processing Record 36 of Set 14 | peleduy
# Processing Record 37 of Set 14 | mwense
# Processing Record 38 of Set 14 | moose factory
# Processing Record 39 of Set 14 | tilichiki
# Processing Record 40 of Set 14 | dipkarpaz
# City not found. Skipping...
# Processing Record 41 of Set 14 | halifax
# Processing Record 42 of Set 14 | alugan
# Processing Record 43 of Set 14 | mahanje
# Processing Record 44 of Set 14 | talca
# Processing Record 45 of Set 14 | gidam
# Processing Record 46 of Set 14 | sechura
# Processing Record 47 of Set 14 | san quintin
# Processing Record 48 of Set 14 | beyneu
# Processing Record 49 of Set 14 | guamuchil
# Processing Record 50 of Set 14 | french harbor
# Processing Record 1 of Set 15 | fairlie
# Processing Record 2 of Set 15 | ossora
# Processing Record 3 of Set 15 | shelburne
# Processing Record 4 of Set 15 | teano
# Processing Record 5 of Set 15 | dubenskiy
# City not found. Skipping...
# Processing Record 6 of Set 15 | shelton
# Processing Record 7 of Set 15 | abu dhabi
# Processing Record 8 of Set 15 | naron
# Processing Record 9 of Set 15 | dudinka
# Processing Record 10 of Set 15 | marolambo
# Processing Record 11 of Set 15 | ballangen
# Processing Record 12 of Set 15 | akyab
# Processing Record 13 of Set 15 | bingol
# Processing Record 14 of Set 15 | kamaishi
# Processing Record 15 of Set 15 | vyazma
# Processing Record 16 of Set 15 | erenhot
# Processing Record 17 of Set 15 | san policarpo
# Processing Record 18 of Set 15 | crateus
# Processing Record 19 of Set 15 | catio
# Processing Record 20 of Set 15 | haimen
# Processing Record 21 of Set 15 | new albany
# Processing Record 22 of Set 15 | pokotylivka
# Processing Record 23 of Set 15 | asau
# Processing Record 24 of Set 15 | illkirch-graffenstaden
# Processing Record 25 of Set 15 | bihac
# Processing Record 26 of Set 15 | wattegama
# Processing Record 27 of Set 15 | san ignacio
# Processing Record 28 of Set 15 | maneadero
# Processing Record 29 of Set 15 | oliveira dos brejinhos
# Processing Record 30 of Set 15 | idenao
# Processing Record 31 of Set 15 | ninghai
# Processing Record 32 of Set 15 | bell ville
# Processing Record 33 of Set 15 | mitsamiouli
# Processing Record 34 of Set 15 | grand gaube
# Processing Record 35 of Set 15 | rundu
# Processing Record 36 of Set 15 | capreol
# Processing Record 37 of Set 15 | porto uniao
# Processing Record 38 of Set 15 | chapais
# Processing Record 39 of Set 15 | san jose de las lajas
# Processing Record 40 of Set 15 | alice springs
# Processing Record 41 of Set 15 | handan
# Processing Record 42 of Set 15 | tamiahua
# Processing Record 43 of Set 15 | shimanovsk
# Processing Record 44 of Set 15 | bijie
# Processing Record 45 of Set 15 | makat
# Processing Record 46 of Set 15 | lhuntshi
# City not found. Skipping...
# Processing Record 47 of Set 15 | fort saint james
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 686

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Banda Aceh      ID   5.5577   95.3222     79.59        80         100
# 1   Punta Arenas      CL -53.1500  -70.9167     55.40        67           0
# 2       Victoria      HK  22.2855  114.1577     73.00        83          99
# 3     Nikolskoye      RU  59.7035   30.7861     42.01        70           0
# 4  Bayonet Point      US  28.3267  -82.6834     80.01        47          16
# 5       Hermanus      ZA -34.4187   19.2345     64.99        83          71
# 6         Cairns      AU -16.9167  145.7667     78.80        83          99
# 7          Kapaa      US  22.0752 -159.3190     71.60        68          40
# 8      Jamestown      US  42.0970  -79.2353     73.99        56           1
# 9       Penzance      GB  50.1186   -5.5371     46.40        53          20
#
#    Wind Speed Current Description
# 0        5.64     overcast clouds
# 1       11.50           clear sky
# 2        1.01     overcast clouds
# 3        6.71           clear sky
# 4        5.01          few clouds
# 5        1.99       broken clouds
# 6        1.14     overcast clouds
# 7       19.57          light rain
# 8        6.91           clear sky
# 9       13.80          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
